# %% [markdown]
# # Autograding for Python/Jupyter/Excel using Otter Grader & GitHub Classroom or Blackboard
#
# Please see the readme for initial installation and setup instructions prior to running the notebook [here](https://github.com/jkuruzovich/otter_helper/blob/master/README.md).
#
# This notebook will allow you to grade an Excel assignment and upload the results to Blackboard.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set Course and Assignment
#  Update set the `course` and `assignment_id` variables to be consistent with the `config.yml` file.
#
#  To run the sample assignments, just keep `course` set to `sample-class` and select `blackboard-excel` for the `assignment_id`.

# %%
#set to what you want to grade
course = 'qm' #Sample assignments. 
assignment_id = 'assignment1'  #Choose blackboard-excel or blackboard-github

# %% [markdown]
# ### Set and Load the Configuration
# This loads the configuration from the `/config/course/config.yml` file.

# %%
from pathlib import Path
import configparser, sys, os, importlib
import pandas as pd
 
cwd_dir = Path.cwd() #For running locally
base_dir = cwd_dir.parent #For running locally
#base_dir='/content/drive/My Drive/autograding'
modules_path = base_dir / 'modules' 
sys.path.append('../modules') # Not sure why appending the mudles path didn't work. 

#Load the autograding library
import autograde as ag
importlib.reload(ag)
cf = ag.get_config(course, assignment_id, base_dir)
cf
# Out:
# {'class_name': 'Quantitative Mangement',
#  'class_id': 'qm',
#  'message_complete': 'Your submission was successfully received and graded.<br>',
#  'message_incomplete': 'If you get this message it is because you did not submit assignment. Please see the TA.<br>',
#  'num_containers': 4,
#  'ignore': ['.ipynb_checkpoints', '.DS_Store'],
#  'requirements': 'config/sample-class/requirements.txt',
#  'roster': 'config/qm/roster.xlsx',
#  'assignments': {'assignment1': {'name': 'assignment1',
#    'type': 'bb',
#    'extension': '.xlsx',
#    'solution_path': 'config/qm/assignment1/solution.xlsx',
#    'solution_sheet': 'Answers',
#    'bb_column': 'ASSIGNMENT'}},
#  'grade_assignment': 'assignment1',
#  'base_path': PosixPath('/Users/jasonkuruzovich/GitHub/otter_helper'),
#  'assignments_path': PosixPath('/Users/jasonkuruzovich/GitHub/otter_helper/assignments/qm/assignment1'),
#  'roster_path': PosixPath('/Users/jasonkuruzovich/GitHub/otter_helper/config/qm/roster.xlsx'),
#  'grades_output_path': PosixPath('/Users/jasonkuruzovich/GitHub/otter_helper/output/qm/assignment1'),
#  'json_output_path': PosixPath('/Users/jasonkuruzovich/GitHub/otter_helper/output/qm/assignment1/json'),
#  'tmp_path': PosixPath('/Users/jasonkuruzovich/GitHub/otter_helper/tmp'),
#  'grade_file': PosixPath('/Users/jasonkuruzovich/GitHub/otter_helper/tmp/final_grades.csv')}

# %% [markdown]
# ### Prepare Grading
# The will copy the assignent files either from the Blackboard or the GitHub classroom files in the `/assignments/course/assignment` folder to the `/tmp/` folder. It will also generate the needed `meta.json` file which maps the identifier (GitHub/Student ID) to the submission file.
#
# *For BlackBoard*
# This makes the assumption that for files collected via Blackboard, each assignment file will be in the form `assignment_identifier_submissiondate`. The identifier is pulled out.  If your pattern is different, minor changes might be needed. [TBD, include a pattern in config.]
#
# *For Github*
# This makes the assumption that for files collected via Github Classroom, each assignment is in a different directory, where the directory name is the student's GitHub id. This GitHub id is used as the identifier for grading and matched with the student id after grading.
#
# The `cleaup=True` option just deletes the tmp folder before starting and is recommended.

# %%
files=ag.prepare_grade(cf,  cleanup=True)  
files
# Out:
# [{'identifier': 'wisnow',
#   'filename': 'Assignment 1_wisnow_attempt_2020-09-08-10-18-54_Assignment 1.xlsx'},
#  {'identifier': 'orefij',
#   'filename': 'Assignment 1_orefij_attempt_2020-09-09-20-41-06_hm_1_v2_student.xlsx'},
#  {'identifier': 'chassb',
#   'filename': 'Assignment 1_chassb_attempt_2020-09-10-13-26-31_hm_1_v2_Chasse_Brandon.xlsx'},
#  {'identifier': 'liy62',
#   'filename': 'Assignment 1_liy62_attempt_2020-09-10-21-36-31_hm_1_v2_student.xlsx'},
#  {'identifier': 'watsoe4',
#   'filename': 'Assignment 1_watsoe4_attempt_2020-09-10-22-18-16_hm_1_v2_student (Autosaved).xlsx'},
#  {'identifier': 'vazqul2',
#   'filename': 'Assignment 1_vazqul2_attempt_2020-09-10-16-53-02_ASSMT1.xlsx'},
#  {'identifier': 'capelm2',
#   'filename': 'Assignment 1_capelm2_attempt_2020-09-10-21-04-48_hm_1_Mikayla Capelle.xlsx'},
#  {'identifier': 'olsenj',
#   'filename': 'Assignment 1_olsenj_attempt_2020-09-09-22-49-05_QM - Assignment 1 - Joshua Olsen.xlsx'},
#  {'identifier': 'thomam12',
#   'filename': 'Assignment 1_thomam12_attempt_2020-09-11-10-30-06_Homework 1.xlsx'},
#  {'identifier': 'yangx16',
#   'filename': 'Assignment 1_yangx16_attempt_2020-09-08-20-01-33_Assignment1 - Xiuwawa Yang.xlsx'},
#  {'identifier': 'naclem',
#   'filename': 'Assignment 1_naclem_attempt_2020-09-10-12-11-55_HW1 Michael Naclerio.xlsx'},
#  {'identifier': 'chaman',
#   'filename': 'Assignment 1_chaman_attempt_2020-09-10-21-20-23_Assignment1_QuantMethods.xlsx'},
#  {'identifier': 'jiangs7',
#   'filename': 'Assignment 1_jiangs7_attempt_2020-09-10-12-10-46_hm_1_v2_shan jiang.xlsx'},
#  {'identifier': 'byersj2',
#   'filename': 'Assignment 1_byersj2_attempt_2020-09-09-12-35-43_Q methods HW1.xlsx'},
#  {'identifier': 'lopeza8',
#   'filename': 'Assignment 1_lopeza8_attempt_2020-09-10-09-45-19_hm_1_v2_Lopez.xlsx'},
#  {'identifier': 'wue6',
#   'filename': 'Assignment 1_wue6_attempt_2020-09-09-23-33-58_hm_1_v2_Eddie Wu.xlsx'},
#  {'identifier': 'zout',
#   'filename': 'Assignment 1_zout_attempt_2020-08-31-19-44-12_hm_1_v2_Zou,Tina.xlsx'},
#  {'identifier': 'schrak2',
#   'filename': 'Assignment 1_schrak2_attempt_2020-09-10-09-33-47_HW 1 Quantitative Methods.xlsx'},
#  {'identifier': 'clarke4',
#   'filename': 'Assignment 1_clarke4_attempt_2020-09-10-21-31-15_hm_1_v2_student.xlsx'},
#  {'identifier': 'mahonp',
#   'filename': 'Assignment 1_mahonp_attempt_2020-09-11-12-22-31_hm_1_v2_Patrick_Mahoney.xlsx'},
#  {'identifier': 'iserne',
#   'filename': 'Assignment 1_iserne_attempt_2020-09-07-14-20-06_hm_1_v2_EverettIsernia.xlsx'},
#  {'identifier': 'morfoc2',
#   'filename': 'Assignment 1_morfoc2_attempt_2020-09-09-20-12-06_hm_1_v2_student.xlsx'},
#  {'identifier': 'friisl',
#   'filename': 'Assignment 1_friisl_attempt_2020-09-10-21-09-04_HW 1 Lilli Friis-Hansen.xlsx'},
#  {'identifier': 'zhengd',
#   'filename': 'Assignment 1_zhengd_attempt_2020-09-10-17-42-24_hm_1_v2_student (1).xlsx'},
#  {'identifier': 'wangp11',
#   'filename': 'Assignment 1_wangp11_attempt_2020-09-10-06-28-43_hw1_Pinhan_Wang.xlsx'},
#  {'identifier': 'roberc6',
#   'filename': 'Assignment 1_roberc6_attempt_2020-09-11-00-02-03_hm_1_v2_student.xlsx'},
#  {'identifier': 'yuc6',
#   'filename': 'Assignment 1_yuc6_attempt_2020-09-08-19-54-08_hm_1_v2_student.xlsx'},
#  {'identifier': 'baoz2',
#   'filename': 'Assignment 1_baoz2_attempt_2020-09-10-19-27-59_hm_1_v2_Zhihao_Bao.xlsx'},
#  {'identifier': 'thompn5',
#   'filename': 'Assignment 1_thompn5_attempt_2020-09-10-20-47-57_hm_1_v2_nadya thompson (1).xlsx'},
#  {'identifier': 'sequea',
#   'filename': 'Assignment 1_sequea_attempt_2020-09-10-09-58-39_hm_1_v2_student.xlsx'},
#  {'identifier': 'liua7',
#   'filename': 'Assignment 1_liua7_attempt_2020-09-10-11-51-34_AlecLiu hw 1.xlsx'},
#  {'identifier': 'smithm23',
#   'filename': 'Assignment 1_smithm23_attempt_2020-09-08-14-35-55_MargaretSmith_661639717_HW1_QuantitativeMethods.xlsx'},
#  {'identifier': 'lombap',
#   'filename': 'Assignment 1_lombap_attempt_2020-09-08-11-35-18_Assignment 1.xlsx'},
#  {'identifier': 'biense2',
#   'filename': 'Assignment 1_biense2_attempt_2020-09-09-18-25-46_hm_1_v2_EricBienstock.xlsx'},
#  {'identifier': 'chenz20',
#   'filename': 'Assignment 1_chenz20_attempt_2020-09-10-22-46-30_hm_1_v2_DavidChen.xlsx'},
#  {'identifier': 'weissa7',
#   'filename': 'Assignment 1_weissa7_attempt_2020-09-08-12-02-03_hw1.xlsx'},
#  {'identifier': 'reilla3',
#   'filename': 'Assignment 1_reilla3_attempt_2020-09-10-13-23-59_Quantitative Methods HW1.xlsx'},
#  {'identifier': 'angrid2',
#   'filename': 'Assignment 1_angrid2_attempt_2020-09-08-20-39-14_QauntStarter.xlsx'},
#  {'identifier': 'curcij',
#   'filename': 'Assignment 1_curcij_attempt_2020-09-10-16-08-21_HW1 QMethods.xlsx'},
#  {'identifier': 'wangx44',
#   'filename': 'Assignment 1_wangx44_attempt_2020-09-08-21-41-46_assignment 1.xlsx'},
#  {'identifier': 'cohenj5',
#   'filename': 'Assignment 1_cohenj5_attempt_2020-09-10-18-26-27_hm_1_v2_Cohen.xlsx'},
#  {'identifier': 'tanh2',
#   'filename': 'Assignment 1_tanh2_attempt_2020-09-03-19-20-02_Hemin Tan 661849064 hm_1_v2_student.xlsx'}]

# %% [markdown]
# ### Running the Grader
#
# This will run a simple autograder based on excel.
#
# Once this runs there will be an output file in `./tmp/final_grades.csv`.  If you have added your solution to this, it is a good practice to double check that your solution passed all of the associate tests.
#
# If you find that nearly all students missed a test, it may also signal an issue with the solution. You can always adjust the solution and rerun.

# %%
grades= ag.excel_grader(cf)
grades
# Out:
# Assignment 1_wisnow_attempt_2020-09-08-10-18-54_Assignment 1.xlsx Index(['variable', 'question', 'answer', 'comments'], dtype='object')
# Assignment 1
# 6                      530 items/month       529.0      3.0      NaN  ...
# 7                                  530       529.0      3.0      3.0  ...
# 8                              19058.8       529.0      3.0      3.0  ...
# 9                            529 items       529.0      3.0      NaN  ...
# 10                  529.412 more items       529.0      3.0      NaN  ...
# 11                           529 items       529.0      3.0      NaN  ...
# 12                             2529.41       529.0      3.0      3.0  ...
# 13                                 320       529.0      3.0      3.0  ...
# 14                                 529       529.0      3.0      3.0  ...
# 15                                 530       529.0      3.0      3.0  ...
# 16                        529.41 items       529.0      3.0      NaN  ...
# 17                             19058.8       529.0      3.0      3.0  ...
# 18                           530 items       529.0      3.0      NaN  ...
# 19                              529.41       529.0      3.0      3.0  ...
# 20                             19058.8       529.0      3.0      3.0  ...
# 21                                 530       529.0      3.0      3.0  ...
# 22  530 items/month additionally to BE       529.0      3.0      NaN  ...
# 23                             529.412       529.0      3.0      3.0  ...
# 24                             529.412       529.0      3.0      3.0  ...
# 25                           530 units       529.0      3.0      NaN  ...
# 26                                 529       529.0      3.0      3.0  ...
# 27                             19058.8       529.0      3.0      3.0  ...
# 28                               19059       529.0      3.0      3.0  ...
# 29                                 530       529.0      3.0      3.0  ...
# 30                           529 items       529.0      3.0      NaN  ...
# 31             529.41 more items/month       529.0      3.0      NaN  ...
# 32                             19058.8       529.0      3.0      3.0  ...
# 33                             529.412       529.0      3.0      3.0  ...
# 34                             19058.8       529.0      3.0      3.0  ...
# 35                529 additional items       529.0      3.0      NaN  ...
# 36                              529.41       529.0      3.0      3.0  ...
# 37                             529.412       529.0      3.0      3.0  ...
# 38                                   0       529.0      3.0      0.0  ...
# 39                             529.412       529.0      3.0      3.0  ...
# 40                                 530       529.0      3.0      3.0  ...
# 41                             21058.8       529.0      3.0      3.0  ...
#
#    answer-C3C  pos-C3C  pts-C3C  \
# 0        45.0      3.0      NaN
# 1        45.0      3.0      NaN
# 2        45.0      3.0      NaN
# 3        45.0      3.0      NaN
# 4        45.0      3.0      NaN
# 5         NaN      NaN      NaN
# 6        45.0      3.0      NaN
# 7        45.0      3.0      NaN
# 8        45.0      3.0      3.0
# 9        45.0      3.0      NaN
# 10       45.0      3.0      NaN
# 11       45.0      3.0      NaN
# 12       45.0      3.0      NaN
# 13       45.0      3.0      NaN
# 14       45.0      3.0      NaN
# 15       45.0      3.0      0.0
# 16       45.0      3.0      NaN
# 17       45.0      3.0      3.0
# 18       45.0      3.0      NaN
# 19       45.0      3.0      NaN
# 20       45.0      3.0      3.0
# 21       45.0      3.0      NaN
# 22       45.0      3.0      NaN
# 23       45.0      3.0      NaN
# 24       45.0      3.0      NaN
# 25       45.0      3.0      0.0
# 26       45.0      3.0      NaN
# 27       45.0      3.0      NaN
# 28       45.0      3.0      NaN
# 29       45.0      3.0      NaN
# 30       45.0      3.0      NaN
# 31       45.0      3.0      NaN
# 32       45.0      3.0      3.0
# 33       45.0      3.0      NaN
# 34       45.0      3.0      NaN
# 35       45.0      3.0      NaN
# 36       45.0      3.0      NaN
# 37       45.0      3.0      NaN
# 38       45.0      3.0      0.0
# 39       45.0      3.0      NaN
# 40       45.0      3.0      NaN
# 41       45.0      3.0      3.0
#
#                                               sub-C3D answer-C3D  pos-C3D  \
# 0   it would take 18.26 years to break even at 50 ...   5.619951      3.0
# 1   It would be very similar to the 45 passengers ...   5.619951      3.0
# 2   This would make first year losses at $986,475,...   5.619951      3.0
# 3                                             5 years   5.619951      3.0
# 4   The town would be able to break even in 5.6 years   5.619951      3.0
# 5                                                 NaN        NaN      NaN
# 6   Break Even at 5.62 years if they went up to 50...   5.619951      3.0
# 7   The service will still make a profit in the 6 ...   5.619951      3.0
# 8                                             18.2648   5.619951      3.0
# 9                                          5.62 years   5.619951      3.0
# 10  This would increase the time to break even to ...   5.619951      3.0
# 11  It would take the town 18.26 years if it avera...   5.619951      3.0
# 12                                     loss increase    5.619951      3.0
# 13                                              18.26   5.619951      3.0
# 14  With 50 passengers and only 3 trips per bus, t...   5.619951      3.0
# 15                                             477300   5.619951      3.0
# 16  If this were the case, the breakeven point wou...   5.619951      3.0
# 17                                              18.26   5.619951      3.0
# 18  This change decreases revenue compared to if t...   5.619951      3.0
# 19                                        18.26 years   5.619951      3.0
# 20                                        18.26 years   5.619951      3.0
# 21                                            6 years   5.619951      3.0
# 22  Town would be able to break even in 5.62 years...   5.619951      3.0
# 23  18.26 years to break even which would be less ...   5.619951      3.0
# 24  annual profit is 213525,  breakeven time is in...   5.619951      3.0
# 25                                                  0   5.619951      3.0
# 26                                            5.61995   5.619951      3.0
# 27                                               1215   5.619951      3.0
# 28                             B/E Time = 18.26 years   5.619951      3.0
# 29  This will still not be enough to break even, s...   5.619951      3.0
# 30  This would cuase the town to break even in 5.6...   5.619951      3.0
# 31  The revenue would increase, the operating cost...   5.619951      3.0
# 32                                              18.26   5.619951      3.0
# 33  This would result in the firm breaking even in...   5.619951      3.0
# 34                                            5.35328   5.619951      3.0
# 35                                          5.6 years   5.619951      3.0
# 36                          18.26 years to break-even   5.619951      3.0
# 37                                            5.61995   5.619951      3.0
# 38                                                  0   5.619951      3.0
# 39                                               5.62   5.619951      3.0
# 40                                        18.26yr BEP   5.619951      3.0
# 41                                            18.2648   5.619951      3.0
#
#     pts-C3D  total possible      STATUS
# 0       NaN    9.0     33.0      GRADED
# 1       NaN   12.0     33.0      GRADED
# 2       NaN    3.0     33.0      GRADED
# 3       NaN   12.0     33.0      GRADED
# 4       NaN   15.0     33.0      GRADED
# 5       NaN    NaN      NaN  FILE-ERROR
# 6       NaN    0.0     33.0      GRADED
# 7       NaN   12.0     33.0      GRADED
# 8       3.0   24.0     33.0      GRADED
# 9       NaN    0.0     33.0      GRADED
# 10      NaN    0.0     33.0      GRADED
# 11      NaN    3.0     33.0      GRADED
# 12      NaN   18.0     33.0      GRADED
# 13      3.0   21.0     33.0      GRADED
# 14      NaN    9.0     33.0      GRADED
# 15      3.0   18.0     33.0      GRADED
# 16      NaN    3.0     33.0      GRADED
# 17      3.0   24.0     33.0      GRADED
# 18      NaN    3.0     33.0      GRADED
# 19      NaN   15.0     33.0      GRADED
# 20      NaN   21.0     33.0      GRADED
# 21      NaN   15.0     33.0      GRADED
# 22      NaN    0.0     33.0      GRADED
# 23      NaN    9.0     33.0      GRADED
# 24      NaN    9.0     33.0      GRADED
# 25      0.0    6.0     33.0      GRADED
# 26      3.0   21.0     33.0      GRADED
# 27      3.0   12.0     33.0      GRADED
# 28      NaN   12.0     33.0      GRADED
# 29      NaN   12.0     33.0      GRADED
# 30      NaN    3.0     33.0      GRADED
# 31      NaN    0.0     33.0      GRADED
# 32      3.0   24.0     33.0      GRADED
# 33      NaN   15.0     33.0      GRADED
# 34      3.0   18.0     33.0      GRADED
# 35      NaN    6.0     33.0      GRADED
# 36      NaN   18.0     33.0      GRADED
# 37      3.0   21.0     33.0      GRADED
# 38      0.0    0.0     33.0      GRADED
# 39      3.0   21.0     33.0      GRADED
# 40      NaN   15.0     33.0      GRADED
# 41      3.0   24.0     33.0      GRADED
#
# [42 rows x 49 columns]

# %% [markdown]
# ### Archive `tmp` Directory and Generate the Upload to Blackboard File
#
# This will archive the `/tmp` directory to the `/output/course/assignment` directory so that you have a persistent copy of the final version.
#
#
# This will loop through the students in your roster file (Blackboard tab) and match it with any graded submissions.  For GitHub classroom it will also match the github ID with the student ID. It will then generate the `/output/course/assignment/upload.csv` file which is ready to be uploaded to blackboard. Scores on each test are included in the `Feedback to Learner` column along with the message included in the `config.yml` file.
#
# **It is important to make sure that your `roster.xslx` file is up to date. If a student entered the class late and isn't on the roster, that student's grade won't be updated.**
#
# **It is important to make sure that the `bb_column` in the `config.yml` file matches the column in Blackboard when you download for offline grading.**

# %%
#Aggregate JSON files for manual grading. 
blackboard=ag.prepare_blackboard_upload(cf, archive=True)
blackboard
# Out:
# complete: 6
# Incomplete: 4
# Total: 10
# Archiving files in
#   Last Name First Name      Username    Student ID         Last Access  \
# 0      Name       Name        fails3        fails3 2020-08-01 22:08:00
# 1      Name       Name     passesAll     passesAll 2020-08-01 22:08:00
# 2      Name       Name  fails2Hidden  fails2Hidden 2020-08-01 22:08:00
# 3      Name       Name  fails3Hidden  fails3Hidden 2020-08-01 22:08:00
# 4      Name       Name        fails2        fails2 2020-08-01 22:08:00
# 5      Name       Name        fails1        fails1 2020-08-01 22:08:00
# 6      Name       Name        fails4        fails4 2020-08-01 22:08:00
# 7      Name       Name      fails3ab      fails3ab 2020-08-01 22:08:00
#
#   Availability  blackboard_excel_test  Grading Notes  Notes Format  \
# 0          Yes                   17.0            NaN           NaN
# 1          Yes                   20.0            NaN           NaN
# 2          Yes                    0.0            NaN           NaN
# 3          Yes                    0.0            NaN           NaN
# 4          Yes                   17.0            NaN           NaN
# 5          Yes                   17.0            NaN           NaN
# 6          Yes                   14.0            NaN           NaN
# 7          Yes                   12.0            NaN           NaN
#
#                                  Feedback to Learner Feedback Format
# 0  Your submission was successfully received and ...            HTML
# 1  Your submission was successfully received and ...            HTML
# 2  If you get this message it is because you did ...             NaN
# 3  If you get this message it is because you did ...             NaN
# 4  Your submission was successfully received and ...            HTML
# 5  Your submission was successfully received and ...            HTML
# 6  Your submission was successfully received and ...            HTML
# 7  Your submission was successfully received and ...            HTML

# %% [markdown]
# ## Upload to Blackboard File
#
# TBD: Flag student submissions which aren't in the roster file.
#
# Upload the `/output/course/assignment/upload.csv` and you are done.
